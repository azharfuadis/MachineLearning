# %% [markdown]
# # Other Popular Machine Learning Methods
# ## Decision tree models with CART
#
# ### Decision Trees

# %%
import os
os.environ["path"]
# Out:
# 'C:\\Users\\HP\\anaconda3;C:\\Users\\HP\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\HP\\anaconda3\\Library\\usr\\bin;C:\\Users\\HP\\anaconda3\\Library\\bin;C:\\Users\\HP\\anaconda3\\Scripts;C:\\Users\\HP\\anaconda3\\bin;C:\\Users\\HP\\anaconda3\\condabin;C:\\Users\\HP\\anaconda3;C:\\Users\\HP\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\HP\\anaconda3\\Library\\usr\\bin;C:\\Users\\HP\\anaconda3\\Library\\bin;C:\\Users\\HP\\anaconda3\\Scripts;C:\\windows\\system32;C:\\windows;C:\\windows\\System32\\Wbem;C:\\windows\\System32\\WindowsPowerShell\\v1.0;C:\\windows\\System32\\OpenSSH;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0;C:\\WINDOWS\\System32\\OpenSSH;C:\\Program Files\\Git\\cmd;C:\\Users\\HP\\anaconda3;C:\\Users\\HP\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\HP\\anaconda3\\Library\\usr\\bin;C:\\User
# ...

# %%
os.environ["path"]=os.environ["path"]+";C:\\Program Files (x86)\\Graphviz2.38\\bin"

# %%
os.environ["path"]
# Out:
# 'C:\\Users\\HP\\anaconda3;C:\\Users\\HP\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\HP\\anaconda3\\Library\\usr\\bin;C:\\Users\\HP\\anaconda3\\Library\\bin;C:\\Users\\HP\\anaconda3\\Scripts;C:\\Users\\HP\\anaconda3\\bin;C:\\Users\\HP\\anaconda3\\condabin;C:\\Users\\HP\\anaconda3;C:\\Users\\HP\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\HP\\anaconda3\\Library\\usr\\bin;C:\\Users\\HP\\anaconda3\\Library\\bin;C:\\Users\\HP\\anaconda3\\Scripts;C:\\windows\\system32;C:\\windows;C:\\windows\\System32\\Wbem;C:\\windows\\System32\\WindowsPowerShell\\v1.0;C:\\windows\\System32\\OpenSSH;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0;C:\\WINDOWS\\System32\\OpenSSH;C:\\Program Files\\Git\\cmd;C:\\Users\\HP\\anaconda3;C:\\Users\\HP\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\HP\\anaconda3\\Library\\usr\\bin;C:\\User
# ...

# %%
import sklearn.datasets as datasets
import pandas as pd
from sklearn import metrics

# %% [markdown]
# ### Preparing the data

# %%
iris=datasets.load_iris()

df = pd.DataFrame(iris.data, columns= iris.feature_names)

y = pd.DataFrame(iris.target)

y.columns = ['labels']

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
y.labels.value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: labels, dtype: int64

# %% [markdown]
# ### The decision tree model

# %%
from sklearn.tree import DecisionTreeClassifier

dtree = DecisionTreeClassifier()

dtree.fit(df, y)
# Out:
# DecisionTreeClassifier()

# %%
pip install pydotplus
# Out:
# ...
#   Created wheel for pydotplus: filename=pydotplus-2.0.2-py3-none-any.whl size=24575 sha256=2d9148635bd3f6082d0ae0dd9cc79806545111dead88bec89793ade10be4838b
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\fe\cd\78\a7e873cc049759194f8271f780640cf96b35e5a48bef0e2f36
# Successfully built pydotplus
# ...

# %%
# conda install graphviz
# conda install -c conda-forge pydotplus
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# recursive splitting in classification trees: gini index to calculate the loss function, thus identifying the best split
# the Gini index (G) is a measure of total variance accross the K classes; it measures the probability of missclassification
from six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus

dot_data = StringIO()

export_graphviz(dtree, out_file=dot_data, filled=True, rounded=True, special_characters=True)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

Image(graph.create_png())
